# %% [markdown]
# ### Audio Classification

# %%
##### Audio Classification Using Machine Learning
#####dataset url https://urbansounddataset.weebly.com/urbansound8k.html

# %%
# !pip install librosa
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting librosa
#   Downloading librosa-0.8.1-py3-none-any.whl (203 kB)
#      |████████████████████████████████| 203 kB 420 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from librosa) (1.20.1)
# Requirement already satisfied: packaging>=20.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from librosa) (20.9)
# Requirement already satisfied: numba>=0.43.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from librosa) (0.53.1)
# Requirement already satisfied: scipy>=1.0.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from librosa) (1.6.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from librosa) (0.24.1)
# Requirement already satisfied: decorator>=3.0.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from librosa) (5.0.6)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
#      |████████████████████████████████| 323 kB 4.1 MB/s eta 0:00:01
# Collecting soundfile>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-macosx_10_5_x86_64.macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (613 kB)
#      |████████████████████████████████| 613 kB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: joblib>=0.14 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from librosa) (1.0.1)
# Collecting pooch>=1.0
#   Downloading pooch-1.4.0-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 2.2 MB/s eta 0:00:011
# Collecting audioread>=2.0.0
#   Downloading audioread-2.1.9.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 2.0 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from numba>=0.43.0->librosa) (52.0.0.post20210125)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from numba>=0.43.0->librosa) (0.36.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->librosa) (2.4.7)
# Requirement already satisfied: requests in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from pooch>=1.0->librosa) (2.25.1)
# Requirement already satisfied: appdirs in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: six>=1.3 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from soundfile>=0.10.2->librosa) (1.14.5)
# Requirement already satisfied: pycparser in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from requests->pooch>=1.0->librosa) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from requests->pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from requests->pooch>=1.0->librosa) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/apple/opt/anaconda3/lib/python3.8/site-packages (from requests->pooch>=1.0->librosa) (2.10)
# Building wheels for collected packages: audioread, resampy
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23141 sha256=5a8692bdac8b8903e11b742a6a15ac0e7a6d03aac0130937206bbff14ef8817d
#   Stored in directory: /private/var/folders/1j/732zcpk15b91f3sdm9g84q7r0000gn/T/pip-ephem-wheel-cache-xy78evc8/wheels/49/5a/e4/df590783499a992a88de6c0898991d1167453a3196d0d1eeb7
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320718 sha256=895eff7a98f7f142f548c12ab643495b33929ba747c746faaba39d1caa18992a
#   Stored in directory: /private/var/folders/1j/732zcpk15b91f3sdm9g84q7r0000gn/T/pip-ephem-wheel-cache-xy78evc8/wheels/6f/d1/5d/f13da53b1dcbc2624ff548456c9ffb526c914f53c12c318bb4
# Successfully built audioread resampy
# Installing collected packages: soundfile, resampy, pooch, audioread, librosa
# Successfully installed audioread-2.1.9 librosa-0.8.1 pooch-1.4.0 resampy-0.2.2 soundfile-0.10.3.post1

# %%
# Import libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import IPython.display as ipd
import librosa
import librosa.display

# %%
# File path
filename = 'Datasets/4918-3-3-0.wav'

# %%
# Plot Sound
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data
# Out:
# array([-0.00040812, -0.0003428 , -0.00046802, ..., -0.00163855,
#        -0.00189345,  0.        ], dtype=float32)

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wav_audio = wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wav_audio
# Out:
# array([[-24, -26],
#        [ -9, -10],
#        [ -5,  -7],
#        ...,
#        [-54, -58],
#        [-60, -60],
#        [-62, -52]], dtype=int16)

# %%
metadata = pd.read_csv('Datasets/UrbanSound8K.csv')

# %%
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing
# 5  children_playing
# 6  children_playing
# 7  children_playing
# 8  children_playing
# 9          car_horn

# %%
### Check whether the dataset is imbalanced
metadata['class'].value_counts()
# Out:
# dog_bark            1000
# street_music        1000
# children_playing    1000
# air_conditioner     1000
# drilling            1000
# jackhammer          1000
# engine_idling       1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64
